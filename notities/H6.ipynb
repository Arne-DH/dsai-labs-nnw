# %%
	
# Package imports
import numpy as np;                                  # "Scientific computing"
import scipy.stats as stats;                         # Statistical tests

import pandas as pd;                                 # Dataframe
import matplotlib.pyplot as plt;                     # Basic visualisation
from statsmodels.graphics.mosaicplot import mosaic;  # Mosaic plot
import seaborn as sns;

# %%
# multi dim data

penguins = sns.load_dataset('penguins') # Load the Palmer Penguins demo dataset
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# # 2D

# %%
sns.relplot(data=penguins,  x='flipper_length_mm', y='body_mass_g');

# %% [markdown]
# Wiskundige functie met x & y as

# %% [markdown]
# # 4D

# %%
sns.relplot(data=penguins,
            x='flipper_length_mm', y='body_mass_g', 
            hue='species', style='sex');

# %% [markdown]
# Op een 2de as 4D data weergeven

# %% [markdown]
# # 5D

# %%
sns.relplot(data=penguins,
            x='bill_depth_mm', y='bill_length_mm',
            size='body_mass_g', 
            hue='species', style='sex');

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
male_chinstrap = penguins[(penguins['species'] == 'Chinstrap') & (penguins['sex'] == 'Male')]
male_chinstrap.head()
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 153  Chinstrap  Dream            50.0           19.5              196.0
# 154  Chinstrap  Dream            51.3           19.2              193.0
# 156  Chinstrap  Dream            52.7           19.8              197.0
# 159  Chinstrap  Dream            51.3           18.2              197.0
# 161  Chinstrap  Dream            51.3           19.9              198.0
#
#      body_mass_g   sex
# 153       3900.0  Male
# 154       3650.0  Male
# 156       3725.0  Male
# 159       3750.0  Male
# 161       3700.0  Male

# %%
male_chinstrap = male_chinstrap.groupby('flipper_length_mm')['body_mass_g'].mean().reset_index()
male_chinstrap.head(10)
# Out:
#    flipper_length_mm  body_mass_g
# 0              187.0  3250.000000
# 1              191.0  3400.000000
# 2              193.0  3741.666667
# 3              194.0  3775.000000
# 4              195.0  4000.000000
# 5              196.0  3725.000000
# 6              197.0  3675.000000
# 7              198.0  3700.000000
# 8              200.0  3800.000000
# 9              201.0  4160.000000

# %%
sns.relplot(data=male_chinstrap,  x='flipper_length_mm', y='body_mass_g');

# %% [markdown]
# *Relplot gebruiken bij alles boven 2D*

# %%
sns.scatterplot(data=male_chinstrap, x='flipper_length_mm', y='body_mass_g');

# %% [markdown]
# *Zelfde als hierboven maar 2D+ is niet mogelijk*

# %%
sns.lmplot(data=male_chinstrap, x='flipper_length_mm', y='body_mass_g');

# %% [markdown]
# LinearRegression in 2D
#
# Bereken numerieke waarde : ax + b ofz idk
#
# *Het getal voor x is a en het getal dat geen x ofzo heeft en apart staat is b want u vergelijking is ax + b*

# %%
from sklearn.linear_model import LinearRegression

male_chinstrap_x = male_chinstrap.flipper_length_mm.values.reshape(-1,1)
male_chinstrap_y = male_chinstrap.body_mass_g

weight_model = LinearRegression().fit(male_chinstrap_x, male_chinstrap_y)

print(f"Regression line: ŷ = {weight_model.intercept_:.4f} + {weight_model.coef_[0]:.4f} x")
# Out:
# Regression line: ŷ = -3868.3320 + 38.8323 x

# %% [markdown]
# # Covariance
#
# Calculate the correlation coefficient and the coefficient of determination.

# %%
# Calculate covar using the formula
covar = sum((cats.Hwt - cats.Hwt.mean()) * 
            (cats.Bwt - cats.Bwt.mean())) / (len(cats) - 1)
        
print(f"Cov(x,y) = {covar}")

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/d/d4/Correlation_examples2.svg" width="800"/>
